# %% [markdown]
# # Generate a dataset for preference alignment
#
# This notebook will guide you through the process of generating a dataset for preference alignment. We'll use the `distilabel` package to generate a dataset for preference alignment.
#
# So let's dig in to some preference alignment datasets.
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#     <h2 style='margin: 0;color:blue'>Exercise: Generate a dataset for preference alignment</h2>
#     <p>Now that you've seen how to generate a dataset for preference alignment, try generating a dataset for preference alignment.</p>
#     <p><b>Difficulty Levels</b></p>
#     <p>🐢 Generate a dataset for preference alignment</p>
#     <p>🐕 Generate a dataset for preference alignment with response evolution</p>
#     <p>🦁 Generate a dataset for preference alignment with response evolution and model pooling</p>
# </div>

# %% [markdown]
# ## Install dependencies
#
# Instead of transformers, you can also install `vllm` or `hf-inference-endpoints`.

# %%
# !pip install "distilabel[hf-transformers,outlines,instructor]"
# Out:
# WARNING: Ignoring invalid distribution ~vidia-cublas-cu12 (/home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~vidia-cublas-cu12 (/home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages)
# Requirement already satisfied: distilabel[hf-transformers,instructor,outlines] in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (1.5.3)
# Requirement already satisfied: datasets>=2.16.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (3.6.0)
# Requirement already satisfied: httpx>=0.25.2 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (0.27.2)
# Requirement already satisfied: jinja2>=3.1.2 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (3.1.6)
# Requirement already satisfied: multiprocess>=0.70 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (0.70.16)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (3.5)
# Requirement already satisfied: orjson>=3.10.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (3.10.18)
# Requirement already satisfied: portalocker>=2.8.2 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (3.2.0)
# Requirement already satisfied: pydantic>=2.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (2.11.7)
# Requirement already satisfied: rich>=13.5.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (14.0.0)
# Requirement already satisfied: scipy>=1.10.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (1.16.0)
# Requirement already satisfied: setuptools in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (78.1.1)
# Requirement already satisfied: tblib>=3.0.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (3.1.0)
# Requirement already satisfied: typer>=0.9.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (0.16.0)
# Requirement already satisfied: universal-pathlib>=0.2.2 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (0.2.6)
# Requirement already satisfied: torch>=2.0.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (2.4.1+cu121)
# Requirement already satisfied: transformers>=4.34.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (4.53.0.dev0)
# Requirement already satisfied: instructor>=1.2.3 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (1.9.0)
# Requirement already satisfied: numba>=0.54.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (0.61.2)
# Requirement already satisfied: outlines>=0.0.40 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from distilabel[hf-transformers,instructor,outlines]) (1.0.2)
# Requirement already satisfied: filelock in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (0.3.8)
# Requirement already satisfied: pandas in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2.3.0)
# Requirement already satisfied: requests>=2.32.2 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (4.67.1)
# Requirement already satisfied: xxhash in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (3.5.0)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (0.33.0)
# Requirement already satisfied: packaging in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (3.12.13)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (6.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (3.10)
# Requirement already satisfied: anyio in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (4.9.0)
# Requirement already satisfied: certifi in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (1.0.9)
# Requirement already satisfied: sniffio in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->distilabel[hf-transformers,instructor,outlines]) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (1.1.5)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.16)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.10.0)
# Requirement already satisfied: mkdocs-material>=9.5.49 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (9.6.14)
# Requirement already satisfied: mkdocs>=1.6.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.6.1)
# Requirement already satisfied: openai<2.0.0,>=1.70.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.92.3)
# Requirement already satisfied: pre-commit>=4.2.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (4.2.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.33.2)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (9.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from jinja2>=3.1.2->distilabel[hf-transformers,instructor,outlines]) (3.0.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from openai<2.0.0,>=1.70.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from pydantic>=2.0->distilabel[hf-transformers,instructor,outlines]) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from pydantic>=2.0->distilabel[hf-transformers,instructor,outlines]) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from rich>=13.5.0->distilabel[hf-transformers,instructor,outlines]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from rich>=13.5.0->distilabel[hf-transformers,instructor,outlines]) (2.19.2)
# Requirement already satisfied: click>=8.0.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from typer>=0.9.0->distilabel[hf-transformers,instructor,outlines]) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from typer>=0.9.0->distilabel[hf-transformers,instructor,outlines]) (1.5.4)
# Requirement already satisfied: mdurl~=0.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.5.0->distilabel[hf-transformers,instructor,outlines]) (0.1.2)
# Requirement already satisfied: ghp-import>=1.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.1.0)
# Requirement already satisfied: markdown>=3.3.6 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (3.8.2)
# Requirement already satisfied: mergedeep>=1.3.4 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.3.4)
# Requirement already satisfied: mkdocs-get-deps>=0.2.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.2.0)
# Requirement already satisfied: pathspec>=0.11.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.12.1)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.1)
# Requirement already satisfied: watchdog>=2.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from ghp-import>=1.0->mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.2.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (4.3.8)
# Requirement already satisfied: babel~=2.10 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.17.0)
# Requirement already satisfied: backrefs~=5.7.post1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (5.9)
# Requirement already satisfied: colorama~=0.4 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.4.6)
# Requirement already satisfied: mkdocs-material-extensions~=1.3 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.3.1)
# Requirement already satisfied: paginate~=0.5 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.5.7)
# Requirement already satisfied: pymdown-extensions~=10.2 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from mkdocs-material>=9.5.49->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (10.16)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from numba>=0.54.0->distilabel[hf-transformers,instructor,outlines]) (0.44.0)
# Requirement already satisfied: interegular in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (0.3.3)
# Requirement already satisfied: lark in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (1.2.2)
# Requirement already satisfied: cloudpickle in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (3.1.1)
# Requirement already satisfied: diskcache in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (5.6.3)
# Requirement already satisfied: referencing in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (0.36.2)
# Requirement already satisfied: jsonschema in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (4.24.0)
# Requirement already satisfied: pillow in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (11.0.0)
# Requirement already satisfied: iso3166 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (2.1.1)
# Requirement already satisfied: airportsdata in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (20250622)
# Requirement already satisfied: outlines_core==0.1.26 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (0.1.26)
# Requirement already satisfied: genson in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (1.3.0)
# Requirement already satisfied: cfgv>=2.0.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (2.6.12)
# Requirement already satisfied: nodeenv>=0.11.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (20.31.2)
# Requirement already satisfied: six>=1.5 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from python-dateutil>=2.8.1->ghp-import>=1.0->mkdocs>=1.6.1->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (1.17.0)
# Requirement already satisfied: sympy in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (1.14.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (12.6.85)
# Requirement already satisfied: regex!=2019.12.17 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from transformers>=4.34.1->distilabel[hf-transformers,instructor,outlines]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from transformers>=4.34.1->distilabel[hf-transformers,instructor,outlines]) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from transformers>=4.34.1->distilabel[hf-transformers,instructor,outlines]) (0.5.3)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from virtualenv>=20.10.0->pre-commit>=4.2.0->instructor>=1.2.3->distilabel[hf-transformers,instructor,outlines]) (0.3.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from jsonschema->outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from jsonschema->outlines>=0.0.40->distilabel[hf-transformers,instructor,outlines]) (0.25.1)
# Requirement already satisfied: pytz>=2020.1 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from pandas->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from pandas->datasets>=2.16.0->distilabel[hf-transformers,instructor,outlines]) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages (from sympy->torch>=2.0.0->distilabel[hf-transformers,instructor,outlines]) (1.3.0)
# WARNING: Ignoring invalid distribution ~vidia-cublas-cu12 (/home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~vidia-cublas-cu12 (/home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~vidia-cublas-cu12 (/home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~vidia-cublas-cu12 (/home/gpogoncheff/anaconda3/envs/smol_course/lib/python3.12/site-packages)

# %% [markdown]
# ## Start synthesizing
#
# As we've seen in the previous notebook, we can create a distilabel pipeline for preference dataset generation. The bare minimum pipline is already provided. You can continue work on this pipeline to generate a large dataset for preference alignment. Swap out models, model providers and generation arguments to see how they affect the quality of the dataset. Experiment small, scale up later.
#
# Check out the [distilabel components gallery](https://distilabel.argilla.io/latest/components-gallery/) for information about the processing classes and how to use them.
#
# An example of loading data from the Hub instead of dictionaries is provided below.
#
# ```python
# from datasets import load_dataset
#
# with Pipeline(...) as pipeline:
#     ...
#
# if __name__ == "__main__:
#     dataset = load_dataset("my-dataset", split="train")
#     distiset = pipeline.run(dataset=dataset)
# ```
#
# Don't forget to push your dataset to the Hub after running the pipeline!

# %%
from distilabel.llms import TransformersLLM
from distilabel.pipeline import Pipeline
from distilabel.steps import GroupColumns, LoadDataFromDicts
from distilabel.steps.tasks import TextGeneration

with Pipeline() as pipeline:
    data = LoadDataFromDicts(data=[{"instruction": "What is synthetic data?"}])
    llm_a = TransformersLLM(model="HuggingFaceTB/SmolLM2-1.7B-Instruct")
    gen_a = TextGeneration(llm=llm_a)
    llm_b = TransformersLLM(model="Qwen/Qwen2.5-1.5B-Instruct")
    gen_b = TextGeneration(llm=llm_b)
    group = GroupColumns(columns=["generation"])
    data >> [gen_a, gen_b] >> group

distiset = pipeline.run()

# %%
data_row = distiset["default"]["train"][0]
print(f"Instruction: {data_row['instruction']}")
print(f"Generation 1: {data_row['grouped_generation'][0]}")
print(f"Generation 2: {data_row['grouped_generation'][1]}")
# Out:
# Instruction: What is synthetic data?
# Generation 1: Synthetic data, also known as simulated or artificial data, refers to artificially generated data that mimics real-world patterns and characteristics. It's created using algorithms and statistical models to mimic the properties of real data, but it doesn't actually represent any specific real-world phenomenon. Synthetic data can be used in various fields such as machine learning, data science, and research. It's often used when collecting real data is difficult, expensive, or impossible due to privacy concerns, regulatory restrictions, or other reasons. For example, synthetic data might be used for training machine learning models on sensitive topics like healthcare or finance without revealing actual personal information.
# Generation 2: Synthetic data refers to data that has been generated artificially rather than being collected from real-world sources. It can be used in various applications where privacy concerns or the need for large amounts of data exist.
#
# Here are some key points about synthetic data:
#
# 1. Generation: Synthetic data is typically created using algorithms and machine learning techniques based on existing data.
#
# 2. Privacy: Unlike real-world data, synthetic data does not contain personally identifiable information (PII), making it suitable for use in scenarios requiring strict privacy protection.
#
# 3. Scalability: Synthetic data can be easily scaled up or down as needed, which is useful when dealing with large datasets.

# %% [markdown]
# ## 🌯 That's a wrap
#
# You've now seen how to generate a dataset for preference alignment. You could use this to:
#
# - Generate a dataset for preference alignment.
# - Create evaluation datasets for preference alignment.
#
# Next
#
# 🏋️‍♂️ Fine-tune a model with preference alignment with a synthetic dataset based on the [preference tuning chapter](../../2_preference_alignment/README.md)
